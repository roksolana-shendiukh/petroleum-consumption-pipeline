-- %%
SELECT COUNT(*) AS bad_value_count
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
WHERE TRY_CAST(value AS DECIMAL(10,3)) IS NULL

-- %%
SELECT value
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
WHERE TRY_CAST(value AS DECIMAL(10,3)) IS NULL
LIMIT 20

-- %%
SELECT DISTINCT period, LENGTH(period) AS len
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
ORDER BY len, period
LIMIT 50

-- %%
SELECT LENGTH(period) AS len, COUNT(*) AS cnt
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
GROUP BY LENGTH(period)

-- %%
SELECT 
  COUNT(*) AS total_rows,
  COUNT(*) - COUNT(`series`) AS null_series,
  COUNT(*) - COUNT(period) AS null_period,
  COUNT(*) - COUNT(value) AS null_value
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw

-- %%
SELECT COUNT(*) AS trimmed_mismatch_count
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
WHERE `product-name` <> TRIM(`product-name`)
