-- %%
DESCRIBE DETAIL dbr_dev_ua5816bd.roksolana_shendiu770_silver.petroleum_prices

-- %%
ALTER TABLE dbr_dev_ua5816bd.roksolana_shendiu770_silver.petroleum_prices
CLUSTER BY (series_bk);

-- %%
OPTIMIZE dbr_dev_ua5816bd.roksolana_shendiu770_silver.petroleum_prices;

-- %%
DESCRIBE DETAIL dbr_dev_ua5816bd.roksolana_shendiu770_silver.petroleum_prices

-- %%
VACUUM dbr_dev_ua5816bd.roksolana_shendiu770_silver.petroleum_prices DRY RUN
