-- %%
DESCRIBE dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_raw

-- %%
DESCRIBE dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw

-- %%
SELECT series, `series-description`, `product-name`, units
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
LIMIT 20

-- %%
SELECT series, period, COUNT(*) 
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_raw
GROUP BY series, period
HAVING COUNT(*) > 1

-- %%
SELECT `series`, duoarea, period, COUNT(DISTINCT product) AS distinct_products
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_raw
GROUP BY `series`, duoarea, period
HAVING COUNT(DISTINCT product) > 1

-- %%
SELECT `series`, duoarea, period, COUNT(*) AS cnt
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_raw
GROUP BY `series`, duoarea, period
HAVING COUNT(*) > 1

-- %%
SELECT `series`, period, COUNT(*) AS cnt
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
GROUP BY `series`, period
HAVING COUNT(*) > 1

-- %%
SELECT `series`, COUNT(DISTINCT `product-name`) AS distinct_products, COUNT(DISTINCT units) AS distinct_units
FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_prices_raw
GROUP BY `series`
HAVING COUNT(DISTINCT `product-name`) > 1 OR COUNT(DISTINCT units) > 1
