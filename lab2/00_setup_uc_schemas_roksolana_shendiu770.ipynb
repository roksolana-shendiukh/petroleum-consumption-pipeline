# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dbr_dev_ua5816bd.roksolana_shendiu770_bronze
MANAGED LOCATION 'abfss://roksolanashendiu770@dlsua5816bd.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS dbr_dev_ua5816bd.roksolana_shendiu770_silver
MANAGED LOCATION 'abfss://roksolanashendiu770@dlsua5816bd.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS dbr_dev_ua5816bd.roksolana_shendiu770_gold
MANAGED LOCATION 'abfss://roksolanashendiu770@dlsua5816bd.dfs.core.windows.net/gold';

# %%
# %sql

LIST '/Volumes/dbr_dev_ua5816bd/roksolana_shendiu770/raw_files'
