# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dbr_dev_ua5816bd.roksolana_shendiu770

# %%
# %sql
SELECT current_user()

# %%
# %sql
CREATE TABLE dbr_dev_ua5816bd.roksolana_shendiu770.test_table AS SELECT 1 AS x

# %%
# %sql
SELECT * FROM dbr_dev_ua5816bd.roksolana_shendiu770.test_table

# %%
# %sql
DROP TABLE IF EXISTS dbr_dev_ua5816bd.roksolana_shendiu770.test_table
