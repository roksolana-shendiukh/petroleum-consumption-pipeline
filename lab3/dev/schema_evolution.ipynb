# %%
# %sql
SELECT count(*) FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_consumption_bronze
WHERE _rescued_data IS NOT NULL

# %%
# %sql
DESCRIBE dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_consumption_bronze

# %%
# %sql
SELECT count(*) FROM dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_consumption_bronze
WHERE _rescued_data IS NOT NULL

# %%
# %sql
DESCRIBE dbr_dev_ua5816bd.roksolana_shendiu770_bronze.petroleum_consumption_bronze
